# %% [markdown]
# ![fig1.gif](attachment:fig1.gif)

# %%
 # Edge Detection

# %% [markdown]
# ![fig2.jpg](attachment:fig2.jpg)

# %% [markdown]
# ![fig3.jpg](attachment:fig3.jpg)

# %% [markdown]
# Edges look like steep cliffs
